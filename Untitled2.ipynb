# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error,r2_score
from math import sqrt
import numpy as np

# %%
# Load the scraped stock data into a pandas DataFrame
df = pd.read_csv('Amazon_data.csv')

# Check for missing values
print(df.isnull().sum())  # Count the number of missing values in each column
df.head()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64
#          date    open     high     low   close      volume
# 0  2010-01-04  136.25  136.610  133.14  133.90   7599900.0
# 1  2010-01-05  133.43  135.479  131.81  134.69   8851900.0
# 2  2010-01-06  134.60  134.730  131.65  132.25   7178800.0
# 3  2010-01-07  132.01  132.320  128.80  130.00  11030200.0
# 4  2010-01-08  130.56  133.680  129.03  133.52   9830500.0

# %%
df["date"]=pd.to_datetime(df.date)
df.set_index('date', inplace=True)

# %%
#resampling data by Month
resampled_df=df.resample('M').mean()
#resampling data by Year
resampled_df_d=df.resample('Y').mean()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig, axes = plt.subplots(nrows=5, ncols=3,figsize=(18,18))
sns.lineplot(ax=axes[0,0], x=df.index,y=df.open).set_title("Open Price")
sns.lineplot(ax=axes[0,1], x=resampled_df.index,y=resampled_df.open).set_title("Open Price after resampled by Month")
sns.lineplot(ax=axes[0,2], x=resampled_df_d.index,y=resampled_df_d.open).set_title("Open Price after resampled by Year")

sns.lineplot(ax=axes[1,0], x=df.index,y=df.high).set_title("High Price")
sns.lineplot(ax=axes[1,1], x=resampled_df.index,y=resampled_df.high).set_title("High Price after resampled by Month")
sns.lineplot(ax=axes[1,2], x=resampled_df_d.index,y=resampled_df_d.high).set_title("High Price after resampled by Year")

sns.lineplot(ax=axes[2,0], x=df.index,y=df.low).set_title("Low Price")
sns.lineplot(ax=axes[2,1], x=resampled_df.index,y=resampled_df.low).set_title("Low Price after resampled by Month")
sns.lineplot(ax=axes[2,2], x=resampled_df_d.index,y=resampled_df_d.low).set_title("Low Price after resampled by Year")

sns.lineplot(ax=axes[3,0], x=df.index,y=df.close).set_title("Close Price")
sns.lineplot(ax=axes[3,1], x=resampled_df.index,y=resampled_df.close).set_title("Close Price after resampled by Month")
sns.lineplot(ax=axes[3,2], x=resampled_df_d.index,y=resampled_df_d.close).set_title("Close Price after resampled by Year")

sns.lineplot(ax=axes[4,0], x=df.index,y=df.volume).set_title("Volume")
sns.lineplot(ax=axes[4,1], x=resampled_df.index,y=resampled_df.volume).set_title("Volume after resampled by Month")
sns.lineplot(ax=axes[4,2], x=resampled_df_d.index,y=resampled_df_d.volume).set_title("Volume after resampled by Year")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## From above graph we can say stock price doesn't have any trend or seasonality

# %%
fig, axes = plt.subplots(nrows=3, ncols=1,figsize=(12,10))


sns.lineplot(x=df.index,y=df["close"], ax=axes[0], label='close price')
sns.lineplot(x=df.index,y=df['close'].rolling(90).mean(), ax=axes[0], label='Rolling Mean', color='orange')
sns.lineplot(x=df.index,y=df['close'].rolling(30).std(), ax=axes[0], label='Rolling Standard Deviation', color='purple')
axes[0].legend()


sns.lineplot(x=df.index,y=df["open"], ax=axes[1], label='open price')
sns.lineplot(x=df.index,y=df['open'].rolling(90).mean(), ax=axes[1], label='Rolling Mean', color='orange')
sns.lineplot(x=df.index,y=df['open'].rolling(90).std(), ax=axes[1], label='Rolling Standard Deviation', color='purple')
axes[1].legend()

sns.lineplot(x=df.index,y=df["volume"], ax=axes[2], label='volume')
sns.lineplot(x=df.index,y=df['volume'].rolling(90).mean(), ax=axes[2], label='Rolling Mean', color='orange')
sns.lineplot(x=df.index,y=df['volume'].rolling(90).std(), ax=axes[2], label='Rolling Standard Deviation', color='purple')
axes[2].legend()

plt.show()

# %% [markdown]
# ## From the above picture we can say data is non-stationary

# %%
df
# Out:
#               open     high       low   close      volume
# date
# 2010-01-04  136.25  136.610  133.1400  133.90   7599900.0
# 2010-01-05  133.43  135.479  131.8100  134.69   8851900.0
# 2010-01-06  134.60  134.730  131.6500  132.25   7178800.0
# 2010-01-07  132.01  132.320  128.8000  130.00  11030200.0
# 2010-01-08  130.56  133.680  129.0300  133.52   9830500.0
# ...            ...      ...       ...     ...         ...
# 2022-12-23   83.25   85.780   82.9344   85.25  57433655.0
# 2022-12-27   84.97   85.350   83.0000   83.04  57284035.0
# 2022-12-28   82.80   83.480   81.6900   81.82  58228575.0
# 2022-12-29   82.87   84.550   82.5500   84.18  54995895.0
# 2022-12-30   83.12   84.050   82.4700   84.00  62401194.0
#
# [3272 rows x 5 columns]

# %%
df['update_open'] = df['open'].shift(1)
df['update_high'] = df['high'].shift(1)
df['update_low'] = df['low'].shift(1)
df['update_close'] = df['close'].shift(1)
df['update_volume'] = df['volume'].shift(1)
print(df)
# Out:
#               open     high       low   close      volume  update_open  \
# date
# 2010-01-04  136.25  136.610  133.1400  133.90   7599900.0          NaN
# 2010-01-05  133.43  135.479  131.8100  134.69   8851900.0       136.25
# 2010-01-06  134.60  134.730  131.6500  132.25   7178800.0       133.43
# 2010-01-07  132.01  132.320  128.8000  130.00  11030200.0       134.60
# 2010-01-08  130.56  133.680  129.0300  133.52   9830500.0       132.01
# ...            ...      ...       ...     ...         ...          ...
# 2022-12-23   83.25   85.780   82.9344   85.25  57433655.0        85.52
# 2022-12-27   84.97   85.350   83.0000   83.04  57284035.0        83.25
# 2022-12-28   82.80   83.480   81.6900   81.82  58228575.0        84.97
# 2022-12-29   82.87   84.550   82.5500   84.18  54995895.0        82.80
# 2022-12-30   83.12   84.050   82.4700   84.00  62401194.0        82.87
#
#             update_high  update_low  update_close  update_volume
# date
# 2010-01-04          NaN         NaN           NaN            NaN
# 2010-01-05      136.610    133.1400        133.90      7599900.0
# 2010-01-06      135.479    131.8100        134.69      8851900.0
# 2010-01-07      134.730    131.6500        132.25      7178800.0
# 2010-01-08      132.320    128.8000        130.00     11030200.0
# ...                 ...         ...           ...            ...
# 2022-12-23       85.680     82.2500         83.79     81431314.0
# 2022-12-27       85.780     82.9344         85.25     57433655.0
# 2022-12-28       85.350     83.0000         83.04     57284035.0
# 2022-12-29       83.480     81.6900         81.82     58228575.0
# 2022-12-30       84.550     82.5500         84.18     54995895.0
#
# [3272 rows x 10 columns]

# %%
df.head()
# Out:
#               open     high     low   close      volume  update_open  \
# date
# 2010-01-04  136.25  136.610  133.14  133.90   7599900.0          NaN
# 2010-01-05  133.43  135.479  131.81  134.69   8851900.0       136.25
# 2010-01-06  134.60  134.730  131.65  132.25   7178800.0       133.43
# 2010-01-07  132.01  132.320  128.80  130.00  11030200.0       134.60
# 2010-01-08  130.56  133.680  129.03  133.52   9830500.0       132.01
#
#             update_high  update_low  update_close  update_volume
# date
# 2010-01-04          NaN         NaN           NaN            NaN
# 2010-01-05      136.610      133.14        133.90      7599900.0
# 2010-01-06      135.479      131.81        134.69      8851900.0
# 2010-01-07      134.730      131.65        132.25      7178800.0
# 2010-01-08      132.320      128.80        130.00     11030200.0

# %%
def ploting(v1,v2,v3,X):

    days=[]
    while(1):
        days.append(df[X].iloc[1:(v1+1)].std())
        days.append(df[X].iloc[1:(v2+1)].std())
        days.append(df[X].iloc[1:(v3+1)].std())
        break

    labels = [str(v1)+' Days', str(v2)+' Days', str(v3)+' Days']
    
    # Plotting the values as a bar chart
    plt.bar(labels, days)
    
    # Adding labels and title
    plt.xlabel('Days')
    plt.ylabel('Standard Deviation')
    plt.title('Plotting '+X+' price Standard Deviation by days')
    
    # Displaying the plot
    plt.show()

ploting(2,7,15,'close')
ploting(2,7,15,'high')
ploting(2,7,15,'low')
ploting(2,7,15,'open')

# %%
ploting(7,30,45,'volume')

# %%
df.update_close.fillna(df.close.iloc[1:3].mean(), inplace=True)
df.update_high.fillna(df.high.iloc[1:3].mean(), inplace=True)
df.update_low.fillna(df.low.iloc[1:3].mean(), inplace=True)
df.update_open.fillna(df.open.iloc[1:3].mean(), inplace=True)
df.update_volume.fillna(df.volume.iloc[1:8].mean(), inplace=True)

# %%
main_columns = ['open', 'high','low','close','volume']
updated_columns = ['update_open', 'update_high','update_low','update_close','update_volume']
subset_df = df[main_columns + updated_columns]
correlation_matrix = subset_df.corr()
correlation_matrix = correlation_matrix.loc[['open', 'high','low','close','volume'], ['update_open', 'update_high','update_low','update_close','update_volume']]
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.4f',linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df.drop(["open","high","low","volume"],axis=1,inplace=True)

# %%
start_date="2010-01-04"
end_date="2020-12-31"
val_start_date="2021-01-04"
val_end_date="2021-12-31"
test_start_date="2022-01-03"
test_end_date="2022-12-30"

train_data=df[start_date:end_date]
val_data=df[val_start_date:val_end_date]
test_data=df[test_start_date:test_end_date]

# %%
train_data
# Out:
#               close  update_open  update_high  update_low  update_close  \
# date
# 2010-01-04   133.90      134.015     135.1045     131.730        133.47
# 2010-01-05   134.69      136.250     136.6100     133.140        133.90
# 2010-01-06   132.25      133.430     135.4790     131.810        134.69
# 2010-01-07   130.00      134.600     134.7300     131.650        132.25
# 2010-01-08   133.52      132.010     132.3200     128.800        130.00
# ...             ...          ...          ...         ...           ...
# 2020-12-24  3172.69     3205.000    3210.1300    3184.170       3185.27
# 2020-12-28  3283.96     3193.900    3202.0000    3169.000       3172.69
# 2020-12-29  3322.00     3194.000    3304.0000    3172.690       3283.96
# 2020-12-30  3285.85     3309.940    3350.6500    3281.223       3322.00
# 2020-12-31  3256.93     3341.000    3342.1000    3282.470       3285.85
#
#             update_volume
# date
# 2010-01-04   9.355757e+06
# 2010-01-05   7.599900e+06
# 2010-01-06   8.851900e+06
# 2010-01-07   7.178800e+06
# 2010-01-08   1.103020e+07
# ...                   ...
# 2020-12-24   2.093787e+06
# 2020-12-28   1.451917e+06
# 2020-12-29   5.620728e+06
# 2020-12-30   4.872933e+06
# 2020-12-31   3.209310e+06
#
# [2769 rows x 6 columns]

# %%
# Normalisation
sc = MinMaxScaler()
train_d = sc.fit_transform(train_data)
val_d = sc.fit_transform(val_data)
test_d=sc.fit_transform(test_data)
print(train_d.shape,val_d.shape,test_d.shape)
# Out:
# (2769, 6) (252, 6) (251, 6)

# %%
X, y = train_d[:, 1:], train_d[:, 0]
X_val,y_val=val_d[:, 1:], val_d[:, 0]
X_test,y_test=test_d[:, 1:], test_d[:, 0]

# %%
X = X.reshape(X.shape[0], 1, X.shape[1])
X.shape
# Out:
# (2769, 1, 5)

# %%
X_val = X_val.reshape(X_val.shape[0], 1, X_val.shape[1])
X_val.shape
# Out:
# (252, 1, 5)

# %%
X_test = X_test.reshape(X_test.shape[0], 1, X_test.shape[1])

# %%
print(X.shape,y.shape,X_val.shape,y_val.shape,X_test.shape,y_test.shape)
# Out:
# (2769, 1, 5) (2769,) (252, 1, 5) (252,) (251, 1, 5) (251,)

# %%
# model = Sequential()
# model.add(LSTM(neurons, batch_input_shape=(batch_size, X.shape[1], X.shape[2]), stateful=True))
# model.add(Dense(1))
# model.compile(loss='mean_squared_error', optimizer='adam')
# for i in range(nb_epoch):
#     model.fit(X, y, epochs=1, batch_size=batch_size,validation_data = (X_val, y_val), verbose=0, shuffle=False)
# model.reset_states()
# return model, history.history['loss'], history.history['val_loss']


...
# design network
model = Sequential()
model.add(LSTM(50, batch_input_shape=(1, X.shape[1], X.shape[2]), stateful=True))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
# fit network
for i in range(100):
    model.fit(X, y, epochs=1, batch_size=1, validation_data=(X_val, y_val), verbose=2, shuffle=False)
    model.reset_states()
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.show()
# Out:
# 2769/2769 - 9s - loss: 0.0099 - val_loss: 0.2582 - 9s/epoch - 3ms/step
# 2769/2769 - 7s - loss: 0.0111 - val_loss: 0.1896 - 7s/epoch - 3ms/step
# 2769/2769 - 7s - loss: 0.0087 - val_loss: 0.1778 - 7s/epoch - 2ms/step
# 2769/2769 - 7s - loss: 0.0078 - val_loss: 0.1699 - 7s/epoch - 3ms/step
# 2769/2769 - 7s - loss: 0.0074 - val_loss: 0.1501 - 7s/epoch - 3ms/step
# 2769/2769 - 7s - loss: 0.0069 - val_loss: 0.1390 - 7s/epoch - 3ms/step
# 2769/2769 - 7s - loss: 0.0070 - val_loss: 0.1273 - 7s/epoch - 2ms/step
# 2769/2769 - 7s - loss: 0.0066 - val_loss: 0.1229 - 7s/epoch - 3ms/step
# 2769/2769 - 7s - loss: 0.0066 - val_loss: 0.1192 - 7s/epoch - 3ms/step
# 2769/2769 - 7s - loss: 0.0062 - val_loss: 0.1106 - 7s/epoch - 2ms/step
# 2769/2769 - 6s - loss: 0.0063 - val_loss: 0.1108 - 6s/epoch - 2ms/step
# 2769/2769 - 6s - loss: 0.0063 - val_loss: 0.0997 - 6s/epoch - 2ms/step
# 2769/2769 - 6s - loss: 0.0058 - val_loss: 0.0979 - 6s/epoch - 2ms/step
# 2769/2769 - 7s - loss: 0.0059 - val_loss: 0.0972 - 7s/epoch - 2ms/step
# 2769/2769 - 7s - loss: 0.0057 - val_loss: 0.0917 - 7s/epoch - 3ms/step
# 2769/2769 - 8s - loss: 0.0056 - val_loss: 0.0885 - 8s/epoch - 3ms/step
# 2769/2769 - 8s - loss: 0.0055 - val_loss: 0.0853 - 8s/epoch - 3ms/step
# 2769/2769 - 5s - loss: 0.0055 - val_loss: 0.0831 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0055 - val_loss: 0.0830 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0054 - val_loss: 0.0816 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0053 - val_loss: 0.0841 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0052 - val_loss: 0.0751 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0051 - val_loss: 0.0773 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0051 - val_loss: 0.0760 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0051 - val_loss: 0.0748 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0741 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0769 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0772 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0762 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0750 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0762 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0743 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0742 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0708 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0051 - val_loss: 0.0723 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0690 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0703 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0720 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0735 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0735 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0731 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0714 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0713 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0721 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0689 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0705 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0723 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0686 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0711 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0051 - val_loss: 0.0717 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0051 - val_loss: 0.0726 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0688 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0705 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0701 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0051 - val_loss: 0.0705 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0715 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0690 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0667 - 5s/epoch - 2ms/step
# 2769/2769 - 6s - loss: 0.0050 - val_loss: 0.0672 - 6s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0671 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0678 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0051 - val_loss: 0.0641 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0688 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0657 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0670 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0050 - val_loss: 0.0647 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0656 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0635 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0615 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0643 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0636 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0597 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0593 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0589 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0609 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0049 - val_loss: 0.0591 - 5s/epoch - 2ms/step
# 2769/2769 - 6s - loss: 0.0048 - val_loss: 0.0583 - 6s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0573 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0573 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0568 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0048 - val_loss: 0.0564 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0561 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0047 - val_loss: 0.0564 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0047 - val_loss: 0.0559 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0047 - val_loss: 0.0548 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0548 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0547 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0544 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0545 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0539 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0537 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0535 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0045 - val_loss: 0.0539 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0534 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0046 - val_loss: 0.0530 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0045 - val_loss: 0.0532 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0044 - val_loss: 0.0534 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0045 - val_loss: 0.0529 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0045 - val_loss: 0.0525 - 5s/epoch - 2ms/step
# 2769/2769 - 5s - loss: 0.0044 - val_loss: 0.0521 - 5s/epoch - 2ms/step

# %%
X_test[0].shape
# Out:
# (1, 5)

# %%
print(X_test[:,:,3][0])
# Out:
# [0.97782802]

# %%
predict_value=[]
for i in range(0,X_test.shape[0]):
    a=X_test[i]
    a = a.reshape(1, 1, a.shape[1])
    predict_value.append(model.predict(a,verbose=0))
    try:
        X_test[:,:,3][i+1]=predict_value[0][i]
    except:
        pass

# %%
predict_value=np.array(predict_value)

# %%
predict_value=predict_value.reshape(-1,1)
predict_value.shape
# Out:
# (251, 1)

# %%
rmse = sqrt(mean_squared_error(predict_value, y_test))
print('RMSE: %.3f' % rmse)
# line plot of observed vs predicted
plt.plot(y_test)
plt.plot(predict_value)
plt.show()
# Out:
# RMSE: 0.085

# %%
inv_yhat = np.concatenate((predict_value, test_d[:, 1:]), axis=1)
inv_yhat = sc.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# %%
print(inv_yhat)
# Out:
# [ 2188.13407805  2094.3274136   2757.17626804  2622.43363434
#   2735.38637725  2793.45429002  2782.02750911  2923.40495192
#   2938.69802335  2904.80726378  2912.66435283  2871.12626449
#   2873.35154755  2810.32750275  2661.27418158  2670.49193685
#   2665.65872673  2689.73476674  2709.22383698  2740.77333073
#   2866.05870971  2870.01481253  2885.60765481  2589.80559998
#   2970.54034881  2917.42856806  3013.16887343  3016.54605372
#   2964.04095206  2884.72182403  2928.54863898  2963.64522282
#   2983.76159131  2950.7261303   2890.79020105  2858.93677297
#   2797.70540542  2853.92671392  2951.81973876  2932.8782658
#   2897.23249859  2898.25354347  2855.8783966   2797.13322377
#   2686.46801791  2663.04049009  2743.15246443  2902.61925382
#   2850.0863956   2763.51983153  2849.3603633   2952.99225515
#   3019.56557091  3069.7617233   3072.22809191  3121.88061225
#   3091.48281747  3071.00442414  3110.3346764   3177.34614928
#   3189.32627703  3124.50122802  3079.19181625  3097.63644679
#   3165.77880122  3105.57521943  2995.53751009  2996.63627334
#   2962.33749233  2908.3577243   2936.72215281  2981.52798129
#   2944.27074753  2942.40709279  3027.7668413   2967.38403143
#   2880.02660367  2807.03497997  2831.56662409  2735.96966153
#   2723.98081029  2857.12664875  2298.8089987   2348.26008573
#   2488.21084136  2485.40128272  2342.61202232  2327.94109435
#   2221.34321582  2253.79023776  2188.96102527  2208.93920574
#   2339.68767048  2300.31796425  2357.58767766  2183.31058273
#   2203.6561411   2232.13040628  2218.34094735  2132.96077795
#   2219.84971464  2320.49876761  2386.75446901  2466.78019976
#   2501.81175394  2512.37233192  2464.33920858 -2288.0227877
#    851.75638842  -213.1771146    202.17204698    61.28103789
#    148.25522687   133.93779851   164.44047344   159.75447222
#    171.0890617    169.16870428   175.52703822   178.5517102
#    182.45824774   181.64765706   180.03896616   176.12935557
#    178.29040202   173.40326487   181.13872071   180.43241539
#    183.51269962   182.84346914   182.68604979   179.12062055
#    178.79190358   177.27689106   185.0733122    178.88141848
#    186.88194947   189.58276187   190.52945882   191.54059065
#    190.85877058   186.37876269   188.14526946   191.97250254
#    208.69444202   196.05469945   206.62201831   209.31470201
#    211.70305485   209.43593869   212.55121602   207.13759641
#    215.66867421   210.30144771   214.0158702    212.15399982
#    216.88232979   210.43636442   212.29020522   210.75169876
#    204.61571469   203.41345912   204.89585768   206.21816036
#    204.51965716   199.07332447   200.03409796   197.95423945
#    196.35407378   198.03284999   194.72377241   198.7777171
#    197.58368938   202.54398488   204.4896206    198.99421827
#    194.91965442   198.95575561   196.85983795   185.73282789
#    195.95884019   190.19647924   186.92090778   185.02781127
#    183.71056424   184.40566781   185.04228433   183.94381848
#    182.93100143   182.98036846   190.97237421   186.12617799
#    189.78538476   185.64995473   182.12080728   183.52528921
#    179.75852577   182.96728322   175.29556834   181.63883444
#    185.21397848   181.29534701   185.33997344   186.33564089
#    186.96184871   189.14192822   186.26545645   185.5110728
#    178.13060354   162.44993157   182.71549157   161.86625077
#    166.34576301   161.56132514   156.38244672   164.09946427
#    156.38462759   173.34408392   160.36184523   169.75218682
#    170.74676384   163.88603615   165.59544372   162.52229689
#    163.680935     158.29606326   163.02260888   159.03181036
#    167.37344964   157.42490381   166.72612701   158.08590645
#    164.1475426    158.61853501   157.81607304   155.2815026
#    158.0484351    155.40045929   156.79869599   163.95691451
#    154.36315699   159.42724221   159.98653689   146.79661965
#    155.49889594   151.93673801   155.08998234   148.60396822
#    152.79183831   149.08752714   150.66261278]

# %%
inv_train = sc.inverse_transform(train_d)
inv_valid = sc.inverse_transform(val_d)
inv_test = sc.inverse_transform(test_d)
inv_ytrain = inv_train[:,0]
inv_yvalid = inv_valid[:,0]
inv_ytest = inv_test[:,0]

print(inv_ytrain.shape,inv_yvalid.shape,inv_ytest.shape)
# Out:
# (2769,) (252,) (251,)

# %%
# Plot the data
train = train_data["close"]
valid = val_data["close"]
test = test_data["close"]
test=test.to_frame()
test["predictions"]=inv_yhat

# %%
# Visualize the data
plt.figure(figsize=(16,6))
plt.title('Model')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close Price USD ($)', fontsize=18)
plt.plot(train)
plt.plot(valid)
plt.plot(test[['close','predictions']])
plt.legend(['Train', 'Val', 'Actual', 'Predictions'], loc='upper left')
plt.show()

# %%
print(test)
# Out:
#               close  predictions
# date
# 2022-01-03  3408.09  2188.134078
# 2022-01-04  3350.44  2735.814621
# 2022-01-05  3287.14  2593.310262
# 2022-01-06  3265.08  2674.466676
# 2022-01-07  3251.08  2755.928611
# ...             ...          ...
# 2022-12-23    85.25   155.089982
# 2022-12-27    83.04   148.603968
# 2022-12-28    81.82   152.791838
# 2022-12-29    84.18   149.087527
# 2022-12-30    84.00   150.662613
#
# [251 rows x 2 columns]

# %%
print(X_test[0][X_t=][:].shape)
# Out:
# (1, 5)

# %%
y_test[0]
# Out:
# 1.0000000000000002

# %%
a=X_test[0]
a = a.reshape(a.shape[0], 1, a.shape[1])
a.shape
a.shape
# Out:
# (1, 1, 5)

# %%
X_te
# Out:
#   Cell In[339], line 1
#     X_test[0][[:]]
#                ^
# SyntaxError: invalid syntax

# %%
a=X_test[250]
# Out:
# array([[2.10465550e-05, 3.19926327e-04, 2.62540908e-04, 7.09503438e-04,
#         2.38816982e-01]])

# %%
X_test
# Out:
# array([[[9.91088287e-01, 9.87741141e-01, 9.92001661e-01, 9.77828018e-01,
#          6.25230548e-04]],
#
#        [[9.82633585e-01, 9.95834978e-01, 9.89571631e-01, 1.00000000e+00,
#          4.29978364e-03]],
#
#        [[1.00000000e+00, 1.00000000e+00, 9.90725590e-01, 9.82668274e-01,
#          5.85169380e-03]],
#
#        ...,
#
#        [[6.52443204e-04, 5.59123581e-04, 3.99916964e-04, 3.66777201e-04,
#          2.49175726e-01]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          2.53451796e-01]],
#
#        [[2.10465550e-05, 3.19926327e-04, 2.62540908e-04, 7.09503438e-04,
#          2.38816982e-01]]])

# %%
print(y_test.shape[0])
# Out:
# 251
